# %%
import pandas as pd

# %%
bank=pd.read_csv("datasets\Bank.csv")

# %%
bank
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
'''The bank needs to know the number of male
customers who are:
1. "Graduate"
2. Have the loan status as 'Y (yes)‘
'''
bank[(bank['Education']=='Graduate') & (bank['Loan_Status']=='Y')]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0  Graduate            No
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 4    LP001008    Male      No          0  Graduate            No
# 5    LP001011    Male     Yes          2  Graduate           Yes
# 8    LP001018    Male     Yes          2  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 608  LP002974    Male     Yes          0  Graduate            No
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
'''• To decide on loan approval for female
customers, the bank officer wishes to see past
records of female customers who:
1. Are 'Self Employed'
2. Have an income greater than $4.000
• Help the bank find and display the records of
such customers.'''

bank[(bank['Gender']=='Female') & (bank['Self_Employed']=='Yes') & (bank['ApplicantIncome'] > 4000)]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %%
'''The bank officer wishes to see the history of
loan approval of customers to ensure they
have:
1. More than three dependents,
2. Have 'Rural property area,
3. Have the loan status as 'Approved'
• Help the bank officer accomplish this task and
determine the number of such customers'''

#bank.Dependents.replace('3+',bank.Dependents.mode,inplace='True')

count1=bank[(bank.Dependents > '3') & (bank.Property_Area=='Rural') & (bank.Loan_Status=='Y')];
count1.Dependents.count()
# Out:
# 13

# %%
'''The customer Wamer K' has applied for a bank
loan of USD 290.000. The bank officer needs
to know the average income of the previous
customers for whom a loan worth $290,000 or
more was approved.
• Help the bank officer accomplish this task.'''

bank[(bank.LoanAmount >= 290) & (bank.Loan_Status=='Y')]['ApplicantIncome'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 21      5955
# 67     10750
# 126    23803
# 130    20166
# 155    39999
# 171    51763
# 260     6083
# 278    14583
# 324    15000
# 333    63337
# 372     9323
# 381     5941
# 432    12876
# 506    20833
# 523     7948
# 525    17500
# 536     6133
# 561    19484
# 592     9357
# 604    12000
# Name: ApplicantIncome, dtype: int64>

# %%
'''The bank officer wishes to know why the loan
got rejected for the customers who:
1. Are unmarried
2. self-employed
• Help the bank officer display the record of
such customers. Also, find out how many male
and female customers fall into this category.'''
bank[(bank.Married=='No') & (bank.Self_Employed=='Yes') & (bank.Loan_Status=='N')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 95   LP001326    Male      No          0      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 199  LP001673    Male      No          0      Graduate           Yes
# 245  LP001813    Male      No          0      Graduate           Yes
# 254  LP001844    Male      No          0      Graduate           Yes
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 438  LP002403    Male      No          0      Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# ...

# %%
bank[(bank.Married=='No') & (bank.Self_Employed=='Yes') & (bank.Loan_Status=='N')].groupby('Gender')['Loan_ID'].count()
# Out:
# Gender
# Female    5
# Male      9
# Name: Loan_ID, dtype: int64

# %%
'''The applicant's income and property area play
an important role in the approval of a loan
application. The bank wishes to find out the
applicant's average income by area. How can
this task be accomplished?'''

df1=bank.groupby('Property_Area')['ApplicantIncome'].mean();
df1=pd.DataFrame(df1);df1
# Out:
#                ApplicantIncome
# Property_Area
# Rural              5554.083799
# Semiurban          5292.261803
# Urban              5398.247525

# %%
'''• The bank officer needs to collect information
about married customers.
• Determine the numbers of customers whose
co-applicant's income is less than the average
of the incomes of all co-applicants and have
gotten their loan approved.'''


bank[(bank.CoapplicantIncome < bank.CoapplicantIncome.mean()) & (bank.Loan_Status=='Y') & (bank.Married=='Yes')].count()
# Out:
# Loan_ID              147
# Gender               147
# Married              147
# Dependents           147
# Education            147
# Self_Employed        147
# ApplicantIncome      147
# CoapplicantIncome    147
# LoanAmount           147
# Loan_Amount_Term     147
# Credit_History       147
# Property_Area        147
# Loan_Status          147
# dtype: int64

# %%
'''• As per the previous record of customers who
have applied for a bank loan, the bank officer
needs to know the number of customers who:
1. Are graduates
2. Have an income ranging between 10,256
and150,000.
• Help the bank officer accomplish this task.'''

bank[(bank['Education']=='Graduate') & (bank.ApplicantIncome.between(10256,150000))]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 67   LP001233    Male     Yes          1  Graduate            No
# 102  LP001350    Male     Yes          1  Graduate            No
# 106  LP001369    Male     Yes          2  Graduate            No
# 115  LP001401    Male     Yes          1  Graduate            No
# 119  LP001422  Female      No          0  Graduate            No
# 126  LP001448    Male     Yes         3+  Graduate            No
# 128  LP001451    Male     Yes          1  Graduate           Yes
# 130  LP001469    Male      No          0  Graduate           Yes
# 138  LP001492    Male      No          0  Graduate            No
# 144  LP001508    Male     Yes          2  Graduate            No
# ...
