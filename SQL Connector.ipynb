# %% [markdown]
# Required Libraries

# %%
import mysql.connector
from sqlalchemy import create_engine
import pandas as pd
import pymysql

# %% [markdown]
# Connecting to database and executing etl operations

# %%
mydb=mysql.connector.connect(host='localhost',port=3307,user='root',password='Password')
#host=hostname i.e. localhost for local installation or ipaddress of the server

# %%
mycursor=mydb.cursor()
#A SQL cursor is a database object that retrieves data from result sets one row at a time.
#It is required to fetch result or update table etc.

# %%
query='use world'
mycursor.execute(query)

# %%
query1='show tables'
mycursor.execute(query1)
myresult=mycursor.fetchall()

# %%
myresult
# Out:
# [('city',), ('country',), ('countrylanguage',)]

# %%
query1='select * from city'
mycursor.execute(query1)
myresult=mycursor.fetchone()

# %%
myresult
# Out:
# (1, 'Kabul', 'AFG', 'Kabol', 1780000)

# %%
myresult1=mycursor.fetchall()

# %%
df=pd.DataFrame(myresult1)

# %%
myresult1
# Out:
# [(2, 'Qandahar', 'AFG', 'Qandahar', 237500),
#  (3, 'Herat', 'AFG', 'Herat', 186800),
#  (4, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800),
#  (5, 'Amsterdam', 'NLD', 'Noord-Holland', 731200),
#  (6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (7, 'Haag', 'NLD', 'Zuid-Holland', 440900),
#  (8, 'Utrecht', 'NLD', 'Utrecht', 234323),
#  (9, 'Eindhoven', 'NLD', 'Noord-Brabant', 201843),
#  (10, 'Tilburg', 'NLD', 'Noord-Brabant', 193238),
#  (11, 'Groningen', 'NLD', 'Groningen', 172701),
#  (12, 'Breda', 'NLD', 'Noord-Brabant', 160398),
#  (13, 'Apeldoorn', 'NLD', 'Gelderland', 153491),
#  (14, 'Nijmegen', 'NLD', 'Gelderland', 152463),
#  (15, 'Enschede', 'NLD', 'Overijssel', 149544),
#  (16, 'Haarlem', 'NLD', 'Noord-Holland', 148772),
#  (17, 'Almere', 'NLD', 'Flevoland', 142465),
#  (18, 'Arnhem', 'NLD', 'Gelderland', 138020),
#  (19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (20, '´s-Hertogenbosch', 'NLD', 'Noord-Brabant', 129170),
# ...

# %%
df
# Out:
#          0               1    2              3       4
# 0        2        Qandahar  AFG       Qandahar  237500
# 1        3           Herat  AFG          Herat  186800
# 2        4  Mazar-e-Sharif  AFG          Balkh  127800
# 3        5       Amsterdam  NLD  Noord-Holland  731200
# 4        6       Rotterdam  NLD   Zuid-Holland  593321
# ...    ...             ...  ...            ...     ...
# 4073  4075      Khan Yunis  PSE     Khan Yunis  123175
# 4074  4076          Hebron  PSE         Hebron  119401
# 4075  4077        Jabaliya  PSE     North Gaza  113901
# 4076  4078          Nablus  PSE         Nablus  100231
# 4077  4079           Rafah  PSE          Rafah   92020
#
# [4078 rows x 5 columns]

# %%
df.set_index(0,inplace=True)

# %%
df
# Out:
#                    1    2              3       4
# 0
# 2           Qandahar  AFG       Qandahar  237500
# 3              Herat  AFG          Herat  186800
# 4     Mazar-e-Sharif  AFG          Balkh  127800
# 5          Amsterdam  NLD  Noord-Holland  731200
# 6          Rotterdam  NLD   Zuid-Holland  593321
# ...              ...  ...            ...     ...
# 4075      Khan Yunis  PSE     Khan Yunis  123175
# 4076          Hebron  PSE         Hebron  119401
# 4077        Jabaliya  PSE     North Gaza  113901
# 4078          Nablus  PSE         Nablus  100231
# 4079           Rafah  PSE          Rafah   92020
#
# [4078 rows x 4 columns]

# %% [markdown]
# Getting SQL Data into DataFrame

# %%
query='''select * from city where District like 'B%' '''

# %%
df1=pd.read_sql_query(query,mydb,index_col='ID')
# Out:
# C:\Users\Futurense\AppData\Local\Temp\ipykernel_4592\3084828696.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1=pd.read_sql_query(query,mydb,index_col='ID')

# %%
df1
# Out:
#                      Name CountryCode         District  Population
# ID
# 4          Mazar-e-Sharif         AFG            Balkh      127800
# 39                  Batna         DZA            Batna      183377
# 43                 Biskra         DZA           Biskra      128281
# 44    Blida (el-Boulaida)         DZA            Blida      127284
# 45                 Béjaïa         DZA           Béjaïa      117162
# ...                   ...         ...              ...         ...
# 3779             Quy Nhon         VNM        Binh Dinh      163385
# 3780             Vung Tau         VNM  Ba Ria-Vung Tau      145145
# 3783          Thai Nguyen         VNM         Bac Thai      127643
# 3785           Phan Thiêt         VNM       Binh Thuan      114236
# 4069             Bulawayo         ZWE         Bulawayo      621742
#
# [217 rows x 4 columns]

# %%
query1='use sakila'
mycursor.execute(query1)

# %%
query2='show tables'
mycursor.execute(query2)
myresult=mycursor.fetchall()

# %%
myresult
# Out:
# [('actor',),
#  ('actor_info',),
#  ('address',),
#  ('category',),
#  ('city',),
#  ('country',),
#  ('customer',),
#  ('customer_list',),
#  ('film',),
#  ('film_actor',),
#  ('film_category',),
#  ('film_list',),
#  ('film_text',),
#  ('inventory',),
#  ('language',),
#  ('nicer_but_slower_film_list',),
#  ('payment',),
#  ('rental',),
#  ('sales_by_film_category',),
#  ('sales_by_store',),
#  ('staff',),
#  ('staff_list',),
#  ('store',)]

# %%
mydb1=mysql.connector.connect(host='localhost',port=3307,user='root',password='Password',database='sakila')

# %%
mycursor1=mydb1.cursor()

# %%
mycursor1.execute('''select * from film where title like '%AGENT TRUMAN' ''')

# %%
result=mycursor1.fetchone()

# %%
df2=pd.read_sql_query('''select * from film where title like '%AGENT TRUMAN' ''',mydb1)
# Out:
# C:\Users\Futurense\AppData\Local\Temp\ipykernel_4592\1611502056.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2=pd.read_sql_query('''select * from film where title like '%AGENT TRUMAN' ''',mydb1)

# %%
df2
# Out:
#    film_id         title                                        description  \
# 0        6  AGENT TRUMAN  A Intrepid Panorama of a Robot And a Boy who m...
#
#    release_year  language_id original_language_id  rental_duration  \
# 0          2006            1                 None                3
#
#    rental_rate  length  replacement_cost rating  special_features  \
# 0         2.99     169             17.99     PG  {Deleted Scenes}
#
#           last_update
# 0 2006-02-15 05:03:42

# %%
mydb1.disconnect()

# %%
mycursor1.close()
# Out:
# True

# %%
mydb.disconnect()

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
conn=create_engine('mysql+pymysql://root:Password@localhost:3307/sakila')
#conn2=create_engine('mysql+pymysql://'+'username'+':'+'password'+'@'+'localhost/db')

# %%
query='select * from city'

# %%
data=pd.read_sql(query,conn)

# %%
data
# Out:
#      city_id                  city  country_id         last_update
# 0          1  A Coruña (La Coruña)          87 2006-02-15 04:45:25
# 1          2                  Abha          82 2006-02-15 04:45:25
# 2          3             Abu Dhabi         101 2006-02-15 04:45:25
# 3          4                 Acuña          60 2006-02-15 04:45:25
# 4          5                 Adana          97 2006-02-15 04:45:25
# ..       ...                   ...         ...                 ...
# 595      596                 Zaria          69 2006-02-15 04:45:25
# 596      597          Zeleznogorsk          80 2006-02-15 04:45:25
# 597      598           Zhezqazghan          51 2006-02-15 04:45:25
# 598      599              Zhoushan          23 2006-02-15 04:45:25
# 599      600            Ziguinchor          83 2006-02-15 04:45:25
#
# [600 rows x 4 columns]

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '1.4.39'

# %%
data2=data[(data['city_id'] > 500)]

# %%
data2
# Out:
#      city_id          city  country_id         last_update
# 500      501         Sucre          14 2006-02-15 04:45:25
# 501      502        Suihua          23 2006-02-15 04:45:25
# 502      503       Sullana          74 2006-02-15 04:45:25
# 503      504   Sultanbeyli          97 2006-02-15 04:45:25
# 504      505      Sumqayit          10 2006-02-15 04:45:25
# ..       ...           ...         ...                 ...
# 595      596         Zaria          69 2006-02-15 04:45:25
# 596      597  Zeleznogorsk          80 2006-02-15 04:45:25
# 597      598   Zhezqazghan          51 2006-02-15 04:45:25
# 598      599      Zhoushan          23 2006-02-15 04:45:25
# 599      600    Ziguinchor          83 2006-02-15 04:45:25
#
# [100 rows x 4 columns]

# %%
data2.to_sql('table1',conn,index=False)
# Out:
# 100

# %%
from urllib.parse import quote_plus

# %%
formatt='Password@123'
encoded_password = quote_plus(formatt)
st=f"mysql+pymysql://root:{formatt}@localhost:3307/sakila"
conn1=create_engine(st)

# %%
data1=pd.read_sql('select * from actor',conn)

# %%
data1
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]
